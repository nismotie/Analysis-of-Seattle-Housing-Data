# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import datetime as dt
import seaborn as sns

df = pd.read_csv('kc_house_data.csv')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df_clean['sqf_diff'] = df_clean['sqft_lot'] - df_clean['sqft_living']

df_clean['sqf_diff'].head()
# Out:
# 0    4470
# 1    4672
# 2    9230
# 3    3040
# 4    6400
# Name: sqf_diff, dtype: int64

# %%
remove = df.loc[df['bedrooms'] == 33]

# %%
df_clean = df.drop(remove.index, axis=0, inplace=False)

# %%
df_clean['date'] = df_clean['date'].map(lambda x: dt.datetime.strptime(str(x),'%m/%d/%Y').strftime('%d/%m/%Y'))

# %%
timestamps.sort(df_clean['date'])

df_clean.plot(x='date',y='price', figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-49399c608ac2> in <module>
# ----> 1 timestamps.sort(df_clean['date'])
#       2
#       3 df_clean.plot(x='date',y='price', figsize=(20,10))
#
# NameError: name 'timestamps' is not defined

# %%
#df[df.duplicated(subset='id')].sort_values(by='id')

grouped = df.groupby('condition').median()

grouped.head(40)

grouped.plot.bar(y='price', figsize=(20,10))

# %% [markdown]
# ### Model Var Definition

# %%
# Pre-processing

y = np.log(df_clean['price'])

df_regression = df_clean.loc[:,['bathrooms', 'sqft_lot', 'floors', 'yr_built', 'zipcode']]

x1 = np.log(df_clean['sqft_living'])
x2 = np.log(df_clean['sqft_lot'])
x3 = df_clean['bathrooms']
x4 = df_clean['zipcode']

X = pd.DataFrame([x1, x2 ,x3 ,x4], columns = ['sqf_liv', 'sqf_lot', 'bathroom', 'zipcode'])

X.head()
#X = df_clean.apply(lambda x: np.log(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a211f284ac30> in <module>
#       1 # Pre-processing
#       2
# ----> 3 y = np.log(df_clean['price'])
#       4
#       5 df_regression = df_clean.loc[:,['bathrooms', 'sqft_lot', 'floors', 'yr_built', 'zipcode']]
#
# NameError: name 'np' is not defined

# %%
# Setting up the LEARNER
X = sm.add_constant(X) #x is sqft_living
model_sm = sm.OLS(y,X)

# Actually LEARNING
results = model_sm.fit()

# Evaluating performance
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))

# # Understanding the LEARNED model
est_b = results.params
print(est_b.round(4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-bac09609569c> in <module>
#       1 # Setting up the LEARNER
#       2 X = sm.add_constant(X) #x is sqft_living
# ----> 3 model_sm = sm.OLS(y,X)
#       4
#       5 # Actually LEARNING
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
# ...

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                 1.806e+04
# Date:                Fri, 18 Oct 2019   Prob (F-statistic):               0.00
# Time:                        11:49:59   Log-Likelihood:                -10230.
# No. Observations:               21596   AIC:                         2.046e+04
# Df Residuals:                   21594   BIC:                         2.048e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           6.7232      0.047    142.609      0.000       6.631       6.816
# ...

# %%
plot_df = df_clean.loc[:, ['bedrooms', 'bathrooms', 'sqft_lot', 'sqft_living', 'floors',
                           'sqft_above', 'sqft_basement', 'yr_built', 'zipcode']]

plot_df.head(5)
# Out:
#    bedrooms  bathrooms  sqft_lot  sqft_living  floors  sqft_above  \
# 0         3       1.00      5650         1180     1.0        1180
# 1         3       2.25      7242         2570     2.0        2170
# 2         2       1.00     10000          770     1.0         770
# 3         4       3.00      5000         1960     1.0        1050
# 4         3       2.00      8080         1680     1.0        1680
#
#   sqft_basement  yr_built  zipcode
# 0           0.0      1955    98178
# 1         400.0      1951    98125
# 2           0.0      1933    98028
# 3         910.0      1965    98136
# 4           0.0      1987    98074

# %%
sns.pairplot(plot_df)
